# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests

# Import the API key.
from config import weather_api_key

# %%
# 3.Create a set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4.Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# 5. Perform an API call with OpenWeatherMap and 6. Retrieve the information from the API call

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | huainan
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | doka
# Processing Record 6 of Set 1 | mataram
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | bandarbeyla
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | biu
# Processing Record 12 of Set 1 | pisco
# Processing Record 13 of Set 1 | cherskiy
# Processing Record 14 of Set 1 | seymchan
# Processing Record 15 of Set 1 | ancud
# Processing Record 16 of Set 1 | waingapu
# Processing Record 17 of Set 1 | salym
# Processing Record 18 of Set 1 | mongagua
# Processing Record 19 of Set 1 | miraflores
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | inongo
# Processing Record 22 of Set 1 | kroya
# Processing Record 23 of Set 1 | parrita
# Processing Record 24 of Set 1 | college
# Processing Record 25 of Set 1 | deputatskiy
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | vanimo
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | nicholasville
# Processing Record 35 of Set 1 | ahipara
# Processing Record 36 of Set 1 | fernie
# Processing Record 37 of Set 1 | fortuna
# Processing Record 38 of Set 1 | bellevue
# Processing Record 39 of Set 1 | tongliao
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | sabla
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | kloulklubed
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | salalah
# Processing Record 5 of Set 2 | itu
# Processing Record 6 of Set 2 | benghazi
# Processing Record 7 of Set 2 | rafaela
# Processing Record 8 of Set 2 | korla
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 2 | kahului
# Processing Record 12 of Set 2 | torbay
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | tiksi
# Processing Record 15 of Set 2 | neftcala
# Processing Record 16 of Set 2 | cabo san lucas
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | clyde river
# Processing Record 19 of Set 2 | kavaratti
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | camargo
# Processing Record 23 of Set 2 | sioux lookout
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | wenling
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | iracoubo
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | san vicente
# Processing Record 34 of Set 2 | gernsbach
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 2 | lakhdenpokhya
# Processing Record 38 of Set 2 | fenyi
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | esperance
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | shumskiy
# Processing Record 44 of Set 2 | ulladulla
# Processing Record 45 of Set 2 | forbes
# Processing Record 46 of Set 2 | opuwo
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | igarka
# Processing Record 49 of Set 2 | imbituba
# Processing Record 50 of Set 2 | itaituba
# Processing Record 1 of Set 3 | kamenka
# Processing Record 2 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 5 of Set 3 | burica
# City not found. Skipping...
# Processing Record 6 of Set 3 | veraval
# Processing Record 7 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 3 | oranjemund
# Processing Record 9 of Set 3 | bereda
# Processing Record 10 of Set 3 | praia
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | dalvik
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | magnitka
# Processing Record 15 of Set 3 | galle
# Processing Record 16 of Set 3 | berdigestyakh
# Processing Record 17 of Set 3 | eureka
# Processing Record 18 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 3 | lata
# Processing Record 20 of Set 3 | affery
# Processing Record 21 of Set 3 | rakaia
# Processing Record 22 of Set 3 | beringovskiy
# Processing Record 23 of Set 3 | khovu-aksy
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | kungurtug
# Processing Record 26 of Set 3 | valdemarpils
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | mabaruma
# Processing Record 29 of Set 3 | verkhnevilyuysk
# Processing Record 30 of Set 3 | lakselv
# Processing Record 31 of Set 3 | mugur-aksy
# Processing Record 32 of Set 3 | lewistown
# Processing Record 33 of Set 3 | whitehorse
# Processing Record 34 of Set 3 | palmer
# Processing Record 35 of Set 3 | kokopo
# Processing Record 36 of Set 3 | hue
# Processing Record 37 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 3 | seoul
# Processing Record 39 of Set 3 | labuan
# Processing Record 40 of Set 3 | tazovskiy
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | codrington
# Processing Record 43 of Set 3 | kuytun
# Processing Record 44 of Set 3 | broome
# Processing Record 45 of Set 3 | fairbanks
# Processing Record 46 of Set 3 | saint anthony
# Processing Record 47 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 3 | petropavl
# Processing Record 49 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 3 | vila franca do campo
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | brigantine
# Processing Record 3 of Set 4 | sawtell
# Processing Record 4 of Set 4 | jambi
# Processing Record 5 of Set 4 | chaozhou
# Processing Record 6 of Set 4 | dingle
# Processing Record 7 of Set 4 | chum phae
# Processing Record 8 of Set 4 | vostochnyy
# Processing Record 9 of Set 4 | lagoa
# Processing Record 10 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | jiaxing
# Processing Record 13 of Set 4 | houma
# Processing Record 14 of Set 4 | ulvik
# Processing Record 15 of Set 4 | lashio
# Processing Record 16 of Set 4 | biak
# Processing Record 17 of Set 4 | hithadhoo
# Processing Record 18 of Set 4 | maumere
# Processing Record 19 of Set 4 | krasnyy chikoy
# Processing Record 20 of Set 4 | komsomolskiy
# Processing Record 21 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 4 | stromness
# Processing Record 23 of Set 4 | marsa matruh
# Processing Record 24 of Set 4 | makakilo city
# Processing Record 25 of Set 4 | halden
# Processing Record 26 of Set 4 | nizwa
# Processing Record 27 of Set 4 | sorland
# Processing Record 28 of Set 4 | boyolangu
# Processing Record 29 of Set 4 | khani
# Processing Record 30 of Set 4 | senneterre
# Processing Record 31 of Set 4 | paamiut
# Processing Record 32 of Set 4 | zenzeli
# Processing Record 33 of Set 4 | general roca
# Processing Record 34 of Set 4 | ghanzi
# Processing Record 35 of Set 4 | puerto leguizamo
# Processing Record 36 of Set 4 | talnakh
# Processing Record 37 of Set 4 | geraldton
# Processing Record 38 of Set 4 | constitucion
# Processing Record 39 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 4 | alugan
# Processing Record 41 of Set 4 | yulara
# Processing Record 42 of Set 4 | morros
# Processing Record 43 of Set 4 | tucuman
# Processing Record 44 of Set 4 | usinsk
# Processing Record 45 of Set 4 | buloh kasap
# Processing Record 46 of Set 4 | port-gentil
# Processing Record 47 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 4 | aromashevo
# Processing Record 49 of Set 4 | plettenberg bay
# Processing Record 50 of Set 4 | srednekolymsk
# Processing Record 1 of Set 5 | manbij
# Processing Record 2 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 5 | havre-saint-pierre
# Processing Record 4 of Set 5 | namibe
# Processing Record 5 of Set 5 | genc
# Processing Record 6 of Set 5 | taoudenni
# Processing Record 7 of Set 5 | thinadhoo
# Processing Record 8 of Set 5 | hobyo
# Processing Record 9 of Set 5 | solnechnyy
# Processing Record 10 of Set 5 | port alfred
# Processing Record 11 of Set 5 | nuuk
# Processing Record 12 of Set 5 | kudahuvadhoo
# Processing Record 13 of Set 5 | havoysund
# Processing Record 14 of Set 5 | bagdarin
# Processing Record 15 of Set 5 | sokoni
# Processing Record 16 of Set 5 | ekhabi
# Processing Record 17 of Set 5 | south venice
# Processing Record 18 of Set 5 | saint george
# Processing Record 19 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | cidreira
# Processing Record 21 of Set 5 | richmond
# Processing Record 22 of Set 5 | andenes
# Processing Record 23 of Set 5 | barra patuca
# Processing Record 24 of Set 5 | aksha
# Processing Record 25 of Set 5 | grindavik
# Processing Record 26 of Set 5 | mayumba
# Processing Record 27 of Set 5 | iroquois falls
# Processing Record 28 of Set 5 | faya
# Processing Record 29 of Set 5 | antalaha
# Processing Record 30 of Set 5 | adrar
# Processing Record 31 of Set 5 | dwarka
# Processing Record 32 of Set 5 | urucara
# Processing Record 33 of Set 5 | khatanga
# Processing Record 34 of Set 5 | barra do corda
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | svoge
# Processing Record 37 of Set 5 | bengkulu
# Processing Record 38 of Set 5 | killybegs
# Processing Record 39 of Set 5 | panjab
# Processing Record 40 of Set 5 | thompson
# Processing Record 41 of Set 5 | uberaba
# Processing Record 42 of Set 5 | vardo
# Processing Record 43 of Set 5 | provideniya
# Processing Record 44 of Set 5 | novoomskiy
# Processing Record 45 of Set 5 | xinxiang
# Processing Record 46 of Set 5 | tyrma
# Processing Record 47 of Set 5 | puerto escondido
# Processing Record 48 of Set 5 | mogadishu
# Processing Record 49 of Set 5 | bubaque
# Processing Record 50 of Set 5 | luderitz
# Processing Record 1 of Set 6 | limbang
# Processing Record 2 of Set 6 | bonavista
# Processing Record 3 of Set 6 | qaanaaq
# Processing Record 4 of Set 6 | muskegon
# Processing Record 5 of Set 6 | taybad
# Processing Record 6 of Set 6 | nome
# Processing Record 7 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 8 of Set 6 | hamilton
# Processing Record 9 of Set 6 | umm ruwabah
# City not found. Skipping...
# Processing Record 10 of Set 6 | kruisfontein
# Processing Record 11 of Set 6 | marovoay
# Processing Record 12 of Set 6 | dunedin
# Processing Record 13 of Set 6 | takaka
# Processing Record 14 of Set 6 | palmerston
# Processing Record 15 of Set 6 | daru
# Processing Record 16 of Set 6 | necochea
# Processing Record 17 of Set 6 | comodoro rivadavia
# Processing Record 18 of Set 6 | saldanha
# Processing Record 19 of Set 6 | mareeba
# Processing Record 20 of Set 6 | amot
# Processing Record 21 of Set 6 | portland
# Processing Record 22 of Set 6 | wairoa
# Processing Record 23 of Set 6 | tautira
# Processing Record 24 of Set 6 | caravelas
# Processing Record 25 of Set 6 | orange walk
# Processing Record 26 of Set 6 | vestmanna
# Processing Record 27 of Set 6 | narsaq
# Processing Record 28 of Set 6 | cayenne
# Processing Record 29 of Set 6 | lavrentiya
# Processing Record 30 of Set 6 | tiznit
# Processing Record 31 of Set 6 | arkhangelos
# City not found. Skipping...
# Processing Record 32 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 33 of Set 6 | mondolfo
# Processing Record 34 of Set 6 | lamu
# Processing Record 35 of Set 6 | katangli
# Processing Record 36 of Set 6 | sao felix do xingu
# Processing Record 37 of Set 6 | chokurdakh
# Processing Record 38 of Set 6 | san patricio
# Processing Record 39 of Set 6 | aklavik
# Processing Record 40 of Set 6 | amarante do maranhao
# Processing Record 41 of Set 6 | tosya
# Processing Record 42 of Set 6 | severo-kurilsk
# Processing Record 43 of Set 6 | nishihara
# Processing Record 44 of Set 6 | bowen
# Processing Record 45 of Set 6 | mackay
# Processing Record 46 of Set 6 | kodiak
# Processing Record 47 of Set 6 | lalibela
# Processing Record 48 of Set 6 | honiara
# Processing Record 49 of Set 6 | saint-georges
# Processing Record 50 of Set 6 | bredasdorp
# Processing Record 1 of Set 7 | bestobe
# Processing Record 2 of Set 7 | tuktoyaktuk
# Processing Record 3 of Set 7 | bijie
# Processing Record 4 of Set 7 | vila velha
# Processing Record 5 of Set 7 | mangrol
# Processing Record 6 of Set 7 | rumonge
# Processing Record 7 of Set 7 | hambantota
# Processing Record 8 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 9 of Set 7 | awbari
# Processing Record 10 of Set 7 | mandalgovi
# Processing Record 11 of Set 7 | gat
# Processing Record 12 of Set 7 | maneadero
# Processing Record 13 of Set 7 | gornyy
# Processing Record 14 of Set 7 | north platte
# Processing Record 15 of Set 7 | dejen
# Processing Record 16 of Set 7 | sao miguel do tapuio
# Processing Record 17 of Set 7 | westport
# Processing Record 18 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 7 | lethem
# Processing Record 20 of Set 7 | warrington
# Processing Record 21 of Set 7 | cabedelo
# Processing Record 22 of Set 7 | sohag
# Processing Record 23 of Set 7 | kaduqli
# Processing Record 24 of Set 7 | port lincoln
# Processing Record 25 of Set 7 | victoria
# Processing Record 26 of Set 7 | iqaluit
# Processing Record 27 of Set 7 | pevek
# Processing Record 28 of Set 7 | sug-aksy
# City not found. Skipping...
# Processing Record 29 of Set 7 | tateyama
# Processing Record 30 of Set 7 | sinop
# Processing Record 31 of Set 7 | othonoi
# City not found. Skipping...
# Processing Record 32 of Set 7 | tome-acu
# City not found. Skipping...
# Processing Record 33 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 34 of Set 7 | los alamos
# Processing Record 35 of Set 7 | pangnirtung
# Processing Record 36 of Set 7 | bac lieu
# Processing Record 37 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 7 | luganville
# Processing Record 39 of Set 7 | kizhinga
# Processing Record 40 of Set 7 | bay roberts
# Processing Record 41 of Set 7 | urubicha
# Processing Record 42 of Set 7 | shubarshi
# Processing Record 43 of Set 7 | egvekinot
# Processing Record 44 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 7 | oksfjord
# Processing Record 46 of Set 7 | esso
# Processing Record 47 of Set 7 | makat
# Processing Record 48 of Set 7 | garowe
# Processing Record 49 of Set 7 | pozo colorado
# Processing Record 50 of Set 7 | sao joao da barra
# Processing Record 1 of Set 8 | lufilufi
# Processing Record 2 of Set 8 | irbeyskoye
# Processing Record 3 of Set 8 | ningxiang
# Processing Record 4 of Set 8 | mandera
# Processing Record 5 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 8 | takhatpur
# Processing Record 7 of Set 8 | edd
# Processing Record 8 of Set 8 | beloha
# Processing Record 9 of Set 8 | uruana
# Processing Record 10 of Set 8 | grand gaube
# Processing Record 11 of Set 8 | road town
# Processing Record 12 of Set 8 | maniitsoq
# Processing Record 13 of Set 8 | foz do iguacu
# Processing Record 14 of Set 8 | omsukchan
# Processing Record 15 of Set 8 | hasaki
# Processing Record 16 of Set 8 | wukari
# Processing Record 17 of Set 8 | shelburne
# Processing Record 18 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 19 of Set 8 | atagay
# Processing Record 20 of Set 8 | marang
# Processing Record 21 of Set 8 | latung
# Processing Record 22 of Set 8 | pasareni
# Processing Record 23 of Set 8 | maceio
# Processing Record 24 of Set 8 | nemuro
# Processing Record 25 of Set 8 | parras
# City not found. Skipping...
# Processing Record 26 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 8 | marica
# Processing Record 29 of Set 8 | innisfail
# Processing Record 30 of Set 8 | skala
# Processing Record 31 of Set 8 | ambanja
# Processing Record 32 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 8 | asau
# Processing Record 34 of Set 8 | borba
# Processing Record 35 of Set 8 | cabinda
# Processing Record 36 of Set 8 | laguna
# Processing Record 37 of Set 8 | coquimbo
# Processing Record 38 of Set 8 | maues
# Processing Record 39 of Set 8 | itarema
# Processing Record 40 of Set 8 | ostrovnoy
# Processing Record 41 of Set 8 | ligayan
# Processing Record 42 of Set 8 | lokosovo
# Processing Record 43 of Set 8 | maragogi
# Processing Record 44 of Set 8 | prince george
# Processing Record 45 of Set 8 | mbanza-ngungu
# Processing Record 46 of Set 8 | karratha
# Processing Record 47 of Set 8 | rorvik
# Processing Record 48 of Set 8 | luanda
# Processing Record 49 of Set 8 | phangnga
# Processing Record 50 of Set 8 | san policarpo
# Processing Record 1 of Set 9 | guerrero negro
# Processing Record 2 of Set 9 | dolores
# Processing Record 3 of Set 9 | arman
# Processing Record 4 of Set 9 | kayerkan
# Processing Record 5 of Set 9 | axim
# Processing Record 6 of Set 9 | te anau
# Processing Record 7 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 9 | isangel
# Processing Record 9 of Set 9 | valguarnera caropepe
# Processing Record 10 of Set 9 | mayo
# Processing Record 11 of Set 9 | kirakira
# Processing Record 12 of Set 9 | margate
# Processing Record 13 of Set 9 | brae
# Processing Record 14 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 9 | los llanos de aridane
# Processing Record 16 of Set 9 | ostersund
# Processing Record 17 of Set 9 | baykit
# Processing Record 18 of Set 9 | manggar
# Processing Record 19 of Set 9 | hualmay
# Processing Record 20 of Set 9 | zyryanka
# Processing Record 21 of Set 9 | ust-tsilma
# Processing Record 22 of Set 9 | tsalenjikha
# Processing Record 23 of Set 9 | nikolskoye
# Processing Record 24 of Set 9 | saint-pierre
# Processing Record 25 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 9 | bambanglipuro
# Processing Record 27 of Set 9 | jiazi
# Processing Record 28 of Set 9 | san quintin
# Processing Record 29 of Set 9 | avsyunino
# Processing Record 30 of Set 9 | bilibino
# Processing Record 31 of Set 9 | potsdam
# Processing Record 32 of Set 9 | bom jesus do galho
# Processing Record 33 of Set 9 | booue
# Processing Record 34 of Set 9 | nosy varika
# Processing Record 35 of Set 9 | vanavara
# Processing Record 36 of Set 9 | brainerd
# Processing Record 37 of Set 9 | avera
# Processing Record 38 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 9 | wainwright
# Processing Record 40 of Set 9 | the valley
# Processing Record 41 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 9 | aquiraz
# Processing Record 43 of Set 9 | novyy urengoy
# Processing Record 44 of Set 9 | tilichiki
# Processing Record 45 of Set 9 | oistins
# Processing Record 46 of Set 9 | port hedland
# Processing Record 47 of Set 9 | waitati
# Processing Record 48 of Set 9 | saint-augustin
# Processing Record 49 of Set 9 | sao filipe
# Processing Record 50 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 10 | emilio carranza
# Processing Record 2 of Set 10 | ivanovka
# Processing Record 3 of Set 10 | haines junction
# Processing Record 4 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 10 | kwekwe
# Processing Record 6 of Set 10 | dzerzhinskoye
# Processing Record 7 of Set 10 | fort nelson
# Processing Record 8 of Set 10 | peniche
# Processing Record 9 of Set 10 | van
# Processing Record 10 of Set 10 | meulaboh
# Processing Record 11 of Set 10 | cabildo
# Processing Record 12 of Set 10 | shaunavon
# Processing Record 13 of Set 10 | uyo
# Processing Record 14 of Set 10 | madaoua
# Processing Record 15 of Set 10 | batesville
# Processing Record 16 of Set 10 | shu
# Processing Record 17 of Set 10 | eyl
# Processing Record 18 of Set 10 | leningradskiy
# Processing Record 19 of Set 10 | bathsheba
# Processing Record 20 of Set 10 | kargasok
# Processing Record 21 of Set 10 | tiarei
# Processing Record 22 of Set 10 | nanortalik
# Processing Record 23 of Set 10 | pemangkat
# Processing Record 24 of Set 10 | ihosy
# Processing Record 25 of Set 10 | si racha
# Processing Record 26 of Set 10 | san juan
# Processing Record 27 of Set 10 | minab
# Processing Record 28 of Set 10 | carballo
# Processing Record 29 of Set 10 | alekseyevka
# Processing Record 30 of Set 10 | marshall
# Processing Record 31 of Set 10 | katsuura
# Processing Record 32 of Set 10 | palaiokhora
# City not found. Skipping...
# Processing Record 33 of Set 10 | pundaguitan
# Processing Record 34 of Set 10 | fengzhen
# Processing Record 35 of Set 10 | bell ville
# Processing Record 36 of Set 10 | corpus christi
# Processing Record 37 of Set 10 | tezu
# Processing Record 38 of Set 10 | saldus
# Processing Record 39 of Set 10 | aparecida do taboado
# Processing Record 40 of Set 10 | aksarka
# Processing Record 41 of Set 10 | ravar
# Processing Record 42 of Set 10 | walvis bay
# Processing Record 43 of Set 10 | harper
# Processing Record 44 of Set 10 | lublin
# Processing Record 45 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 10 | belaya gora
# Processing Record 47 of Set 10 | san jose
# Processing Record 48 of Set 10 | goya
# Processing Record 49 of Set 10 | qui nhon
# Processing Record 50 of Set 10 | pantai remis
# Processing Record 1 of Set 11 | tynda
# Processing Record 2 of Set 11 | porto novo
# Processing Record 3 of Set 11 | kargalinskaya
# Processing Record 4 of Set 11 | atenas de san cristobal
# Processing Record 5 of Set 11 | helong
# Processing Record 6 of Set 11 | awjilah
# Processing Record 7 of Set 11 | sorong
# Processing Record 8 of Set 11 | naze
# Processing Record 9 of Set 11 | waipawa
# Processing Record 10 of Set 11 | riohacha
# Processing Record 11 of Set 11 | dryden
# Processing Record 12 of Set 11 | antofagasta
# Processing Record 13 of Set 11 | mandal
# Processing Record 14 of Set 11 | port macquarie
# Processing Record 15 of Set 11 | puerto palomas
# Processing Record 16 of Set 11 | myaundzha
# Processing Record 17 of Set 11 | burnie
# Processing Record 18 of Set 11 | inzhavino
# Processing Record 19 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 11 | port blair
# Processing Record 21 of Set 11 | blind river
# Processing Record 22 of Set 11 | nandi hills
# Processing Record 23 of Set 11 | santa maria
# Processing Record 24 of Set 11 | gagnoa
# Processing Record 25 of Set 11 | vrangel
# Processing Record 26 of Set 11 | quatre cocos
# Processing Record 27 of Set 11 | norman wells
# Processing Record 28 of Set 11 | jalu
# Processing Record 29 of Set 11 | hondo
# Processing Record 30 of Set 11 | kidal
# Processing Record 31 of Set 11 | pacific grove
# Processing Record 32 of Set 11 | micheweni
# Processing Record 33 of Set 11 | zapadnaya dvina
# Processing Record 34 of Set 11 | mana
# Processing Record 35 of Set 11 | akyab
# Processing Record 36 of Set 11 | annamalainagar
# Processing Record 37 of Set 11 | zhigansk
# Processing Record 38 of Set 11 | anandnagar
# Processing Record 39 of Set 11 | broken hill
# Processing Record 40 of Set 11 | astana
# Processing Record 41 of Set 11 | almeirim
# Processing Record 42 of Set 11 | ayan
# Processing Record 43 of Set 11 | sisimiut
# Processing Record 44 of Set 11 | yellowknife
# Processing Record 45 of Set 11 | ilulissat
# Processing Record 46 of Set 11 | lac du bonnet
# Processing Record 47 of Set 11 | aleksandrov gay
# Processing Record 48 of Set 11 | intipuca
# Processing Record 49 of Set 11 | namatanai
# Processing Record 50 of Set 11 | sept-iles
# Processing Record 1 of Set 12 | brokopondo
# Processing Record 2 of Set 12 | afonso bezerra
# Processing Record 3 of Set 12 | marystown
# Processing Record 4 of Set 12 | erenhot
# Processing Record 5 of Set 12 | khandyga
# Processing Record 6 of Set 12 | kutum
# Processing Record 7 of Set 12 | eskisehir
# Processing Record 8 of Set 12 | vyazemskiy
# Processing Record 9 of Set 12 | yabrud
# Processing Record 10 of Set 12 | obanazawa
# Processing Record 11 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 12 | lusambo
# Processing Record 13 of Set 12 | beitbridge
# Processing Record 14 of Set 12 | bangassou
# Processing Record 15 of Set 12 | digby
# Processing Record 16 of Set 12 | bamenda
# Processing Record 17 of Set 12 | qarqin
# Processing Record 18 of Set 12 | west wendover
# Processing Record 19 of Set 12 | balaipungut
# Processing Record 20 of Set 12 | ishigaki
# Processing Record 21 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 12 | sindor
# Processing Record 23 of Set 12 | pinega
# Processing Record 24 of Set 12 | yumbing
# Processing Record 25 of Set 12 | flinders
# Processing Record 26 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 12 | krechevitsy
# Processing Record 28 of Set 12 | kununurra
# Processing Record 29 of Set 12 | upata
# Processing Record 30 of Set 12 | elk city
# Processing Record 31 of Set 12 | labuhan
# Processing Record 32 of Set 12 | sabang
# Processing Record 33 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 12 | seguela
# Processing Record 35 of Set 12 | aswan
# Processing Record 36 of Set 12 | cavalcante
# Processing Record 37 of Set 12 | sobolevo
# Processing Record 38 of Set 12 | funtua
# Processing Record 39 of Set 12 | waddan
# Processing Record 40 of Set 12 | russell
# Processing Record 41 of Set 12 | lerik
# Processing Record 42 of Set 12 | changli
# Processing Record 43 of Set 12 | angoche
# Processing Record 44 of Set 12 | les escoumins
# Processing Record 45 of Set 12 | kytlym
# City not found. Skipping...
# Processing Record 46 of Set 12 | sfantu gheorghe
# Processing Record 47 of Set 12 | mezen
# Processing Record 48 of Set 12 | luang prabang
# Processing Record 49 of Set 12 | wasilla
# Processing Record 50 of Set 12 | tawau
# Processing Record 1 of Set 13 | esqueda
# Processing Record 2 of Set 13 | pasco
# Processing Record 3 of Set 13 | staraya kulatka
# Processing Record 4 of Set 13 | saint andrews
# Processing Record 5 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 13 | skibbereen
# Processing Record 7 of Set 13 | arlit
# Processing Record 8 of Set 13 | barao de melgaco
# Processing Record 9 of Set 13 | yeniseysk
# Processing Record 10 of Set 13 | brownwood
# Processing Record 11 of Set 13 | zhanakorgan
# Processing Record 12 of Set 13 | rincon
# Processing Record 13 of Set 13 | smithers
# Processing Record 14 of Set 13 | roma
# Processing Record 15 of Set 13 | iquitos
# Processing Record 16 of Set 13 | atar
# Processing Record 17 of Set 13 | darhan
# Processing Record 18 of Set 13 | sayyan
# Processing Record 19 of Set 13 | krasnoarmeysk
# Processing Record 20 of Set 13 | ndele
# Processing Record 21 of Set 13 | san jose pinula
# Processing Record 22 of Set 13 | mantua
# Processing Record 23 of Set 13 | houston
# Processing Record 24 of Set 13 | nioki
# Processing Record 25 of Set 13 | campeche
# Processing Record 26 of Set 13 | kouqian
# Processing Record 27 of Set 13 | los algarrobos
# Processing Record 28 of Set 13 | acapulco
# Processing Record 29 of Set 13 | bilma
# Processing Record 30 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 13 | aitape
# Processing Record 32 of Set 13 | san cristobal
# Processing Record 33 of Set 13 | ginda
# Processing Record 34 of Set 13 | manaia
# Processing Record 35 of Set 13 | jardim
# Processing Record 36 of Set 13 | virginia beach
# Processing Record 37 of Set 13 | gushi
# Processing Record 38 of Set 13 | lagos
# Processing Record 39 of Set 13 | pasaje
# Processing Record 40 of Set 13 | itoman
# Processing Record 41 of Set 13 | shenjiamen
# Processing Record 42 of Set 13 | otane
# Processing Record 43 of Set 13 | la ronge
# Processing Record 44 of Set 13 | abu dhabi
# Processing Record 45 of Set 13 | yanam
# Processing Record 46 of Set 13 | verkhnyaya balkariya
# Processing Record 47 of Set 13 | hami
# Processing Record 48 of Set 13 | barranca
# Processing Record 49 of Set 13 | grootfontein
# Processing Record 50 of Set 13 | yar-sale
# Processing Record 1 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 14 | malanje
# Processing Record 3 of Set 14 | pochutla
# Processing Record 4 of Set 14 | letterkenny
# Processing Record 5 of Set 14 | rocha
# Processing Record 6 of Set 14 | ust-kulom
# Processing Record 7 of Set 14 | dickinson
# Processing Record 8 of Set 14 | oranjestad
# Processing Record 9 of Set 14 | nortelandia
# Processing Record 10 of Set 14 | dholka
# Processing Record 11 of Set 14 | morris
# Processing Record 12 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 13 of Set 14 | sola
# Processing Record 14 of Set 14 | tacuarembo
# Processing Record 15 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 14 | luba
# Processing Record 17 of Set 14 | nioro
# Processing Record 18 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 19 of Set 14 | kamaishi
# Processing Record 20 of Set 14 | san andres
# Processing Record 21 of Set 14 | barmer
# Processing Record 22 of Set 14 | kiunga
# Processing Record 23 of Set 14 | gazli
# Processing Record 24 of Set 14 | touros
# Processing Record 25 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 14 | nantucket
# Processing Record 27 of Set 14 | parana
# Processing Record 28 of Set 14 | hokitika
# Processing Record 29 of Set 14 | angol
# Processing Record 30 of Set 14 | vikulovo
# Processing Record 31 of Set 14 | souillac
# Processing Record 32 of Set 14 | magadan
# Processing Record 33 of Set 14 | korgen
# Processing Record 34 of Set 14 | belen
# Processing Record 35 of Set 14 | half moon bay
# Processing Record 36 of Set 14 | merauke
# Processing Record 37 of Set 14 | sohbatpur
# Processing Record 38 of Set 14 | manaus
# Processing Record 39 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 14 | tabou
# Processing Record 41 of Set 14 | eregli
# Processing Record 42 of Set 14 | mamlyutka
# Processing Record 43 of Set 14 | muzhi
# Processing Record 44 of Set 14 | hebertville
# City not found. Skipping...
# Processing Record 45 of Set 14 | praya
# Processing Record 46 of Set 14 | sur
# Processing Record 47 of Set 14 | orizatlan
# Processing Record 48 of Set 14 | vila
# Processing Record 49 of Set 14 | slonim
# Processing Record 50 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 1 of Set 15 | sulangan
# Processing Record 2 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 3 of Set 15 | dauphin
# Processing Record 4 of Set 15 | mitu
# Processing Record 5 of Set 15 | dorado
# Processing Record 6 of Set 15 | henties bay
# Processing Record 7 of Set 15 | galveston
# Processing Record 8 of Set 15 | yarim
# Processing Record 9 of Set 15 | aliaga
# Processing Record 10 of Set 15 | yarada
# Processing Record 11 of Set 15 | yatou
# Processing Record 12 of Set 15 | barra do garcas
# Processing Record 13 of Set 15 | nacala
# Processing Record 14 of Set 15 | okhotsk
# Processing Record 15 of Set 15 | flin flon
# Processing Record 16 of Set 15 | sunndalsora
# Processing Record 17 of Set 15 | tiruchchendur
# Processing Record 18 of Set 15 | nyurba
# Processing Record 19 of Set 15 | sungairaya
# Processing Record 20 of Set 15 | panaba
# Processing Record 21 of Set 15 | ust-kuyga
# Processing Record 22 of Set 15 | kuusamo
# Processing Record 23 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 24 of Set 15 | uusikaupunki
# Processing Record 25 of Set 15 | eatonton
# Processing Record 26 of Set 15 | chegdomyn
# Processing Record 27 of Set 15 | kodinsk
# Processing Record 28 of Set 15 | salihorsk
# Processing Record 29 of Set 15 | xiaoweizhai
# Processing Record 30 of Set 15 | susaki
# Processing Record 31 of Set 15 | takoradi
# Processing Record 32 of Set 15 | paita
# Processing Record 33 of Set 15 | karatuzskoye
# Processing Record 34 of Set 15 | poltavka
# Processing Record 35 of Set 15 | nokia
# Processing Record 36 of Set 15 | teguise
# Processing Record 37 of Set 15 | arcachon
# Processing Record 38 of Set 15 | starogard gdanski
# Processing Record 39 of Set 15 | berlevag
# Processing Record 40 of Set 15 | tuatapere
# Processing Record 41 of Set 15 | cockburn town
# Processing Record 42 of Set 15 | mehamn
# Processing Record 43 of Set 15 | lorengau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new dataframe.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)[["City","Country", "Lat","Lng","Max Temp", "Humidity", "Cloudiness",
                                        "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Longyearbyen      SJ  78.2186   15.6401     19.24        79          20
# 1  Bambous Virieux      MU -20.3428   57.7575     75.22        79          15
# 2          Huainan      CN  32.6264  116.9969     56.39        64          97
# 3     Puerto Ayora      EC  -0.7393  -90.3518     76.96        79          92
# 4             Doka      SD  13.5167   35.7667     85.19        35          55
# 5          Mataram      ID  -8.5833  116.1167     76.01        74          75
# 6         Hermanus      ZA -34.4187   19.2345     59.90        69          68
# 7        Busselton      AU -33.6500  115.3333     54.09        83          17
# 8      Bandarbeyla      SO   9.4942   50.8122     78.64        77           8
# 9           Bethel      US  41.3712  -73.4140     57.67        61          90
#
#    Wind Speed Current Description
# 0        3.44          few clouds
# 1       10.89          few clouds
# 2        5.01          light rain
# 3        9.95     overcast clouds
# 4        3.65       broken clouds
# 5        4.54       broken clouds
# 6        9.44          light rain
# 7        6.91          few clouds
# 8       10.80           clear sky
# 9        6.91     overcast clouds

# %%
# 8. Export the dataframe as a CSV file.
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
